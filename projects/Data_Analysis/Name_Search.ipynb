# %% [markdown]
# # Name Search
#
# This notebook shows how can we use `bash` instead of `python` for specific tasks.
#
# So we have created some files with random numbers, but in two of them there is the name of my friend Julian Triana. One of these two files is a copy of other and just one name was replaced by Julian's.
#
# The task here is finding where Julian is, and of course, show which file we copied into which.
#
# ---
# We are going to use the `os` library, to access to the operative system services

# %%
import os

# %% [markdown]
# We have all our data on a folder, and a couple of trash file+folder inside.

# %%
ls names_files/
# Out:
# 0.dat     20.dat    32.dat    44.dat    56.dat    68.dat    8.dat     91.dat
# 1.dat     21.dat    33.dat    45.dat    57.dat    69.dat    80.dat    92.dat
# 10.dat    22.dat    34.dat    46.dat    58.dat    7.dat     81.dat    93.dat
# 11.dat    23.dat    35.dat    47.dat    59.dat    70.dat    82.dat    94.dat
# 12.dat    24.dat    36.dat    48.dat    6.dat     71.dat    83.dat    95.dat
# 13.dat    25.dat    37.dat    49.dat    60.dat    72.dat    84.dat    96.dat
# 14.dat    26.dat    38.dat    5.dat     61.dat    73.dat    85.dat    97.dat
# 15.dat    27.dat    39.dat    50.dat    62.dat    74.dat    86.dat    98.dat
# 16.dat    28.dat    4.dat     51.dat    63.dat    75.dat    87.dat    99.dat
# 17.dat    29.dat    40.dat    52.dat    64.dat    76.dat    88.dat    test/
# 18.dat    3.dat     41.dat    53.dat    65.dat    77.dat    89.dat    test.dat
# 19.dat    30.dat    42.dat    54.dat    66.dat    78.dat    9.dat
# 2.dat     31.dat    43.dat    55.dat    67.dat    79.dat    90.dat

# %% [markdown]
# Here we introduce an example of how to ignore some of the outputs of a given function

# %%
def f(x):
    return x,2*x,x**3
_,_,a=f(2)
print(a)
# Out:
# 8

# %% [markdown]
# So we can ignore the current file and the folders inside `names_files` so we just keep the names of the files there

# %%
for _,_,file_names in os.walk("names_files"):
    break

# %% [markdown]
# We delete the `test.dat` from the list,

# %%
names=[]
for name in file_names:
    if not name.startswith('t'):
        names.append(name)

# %% [markdown]
# And we build a non extension file list,

# %%
file_names=[(index[:-4]) for index in names]

# %%
file_names.sort()

# %% [markdown]
# We read all the files so we can find Julian revising them all,

# %%
import pandas as pd

# %%
df=pd.DataFrame()
for file in file_names:
    data=pd.read_csv("names_files/"+file+'.dat',header=None)

    if 'Julian Triana' in data.values:
        print(file,list(data.values).index('Julian Triana')+1)
# Out:
# 36 93
# 39 50

# %% [markdown]
# One could also import all the data to a `pd.DataFrame`, if more analysis is needed

# %%
df=pd.DataFrame()
for file in file_names:
    data=pd.read_csv("names_files/"+file+'.dat',header=None)
    df[file]=data.values.reshape(100)

# %%
df
# Out:
#                    0                1              10                11  \
# 0     Joshua Kaufman  Sharon Escobedo     Ethel Woods  Loretta Erickson
# 1   Stephen Delacruz    Charles Davis   Erica Demaire       Luis Kottke
# 2   Ramona Dwaileebe      Matthew Fox    Dennis Bland       Jay Omalley
# 3       April Wagner   Christine Webb   Scott Knowles    John Vastardis
# 2      Sandra Grace  William Patterson    Edwin Strauss  Sharon Hawthorne
# 3      Connie Gross     Charlie Harian     Arthur Swint     Brenda Ashley
# 4   Patricia Eilers    Doris Farruggio     Jacob Willis  Shirley Mccarthy
# ..              ...                ...              ...               ...
# 95    Martha Hinton     Elizabeth Bond  Thomas Trinidad  Marianne Collins
# 96  Dollie Mannings        Eric Miller      Travis Cruz  Henry Stephenson
# 97    Mary Gonzalez            Jay May  Margaret Bailey      James Flores
# 98   Roy Fitzgibbon      Richard Crump  George Beauford       Joseph Lamb
# 99         Lee Shea      Scott Keeling     Austin Bruns  Brady Montgomery
#
#                     99
# 0   Patricia Alexander
# 1          James Beard
# 2         Gustavo Otis
# 3      Frances Spencer
# 4         Mary Stoviak
# ..                 ...
# 95      Douglas Walton
# 96   Christopher Wiles
# 97    Stephanie Musser
# 98     Edward Robinson
# 99      Heath Milewski
#
# [100 rows x 100 columns]

# %% [markdown]
# We can simply look for the places Julian is on the DataFrame

# %%
df=='Julian Triana'
# Out:
#         0      1     10     11     12     13     14     15     16     17  ...  \
# 0   False  False  False  False  False  False  False  False  False  False  ...
# 1   False  False  False  False  False  False  False  False  False  False  ...
# 2   False  False  False  False  False  False  False  False  False  False  ...
# 3   False  False  False  False  False  False  False  False  False  False  ...
# 4   False  False  False  False  False  False  False  False  False  False  ...
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...  ...
# 95  False  False  False  False  False  False  False  False  False  False  ...
# 96  False  False  False  False  False  False  False  False  False  False  ...
# 97  False  False  False  False  False  False  False  False  False  False  ...
# 98  False  False  False  False  False  False  False  False  False  False  ...
# 99  False  False  False  False  False  False  False  False  False  False  ...
#
#        90     91     92     93     94     95     96     97     98     99
# 0   False  False  False  False  False  False  False  False  False  False
# 1   False  False  False  False  False  False  False  False  False  False
# 2   False  False  False  False  False  False  False  False  False  False
# 3   False  False  False  False  False  False  False  False  False  False
# 4   False  False  False  False  False  False  False  False  False  False
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 95  False  False  False  False  False  False  False  False  False  False
# 96  False  False  False  False  False  False  False  False  False  False
# 97  False  False  False  False  False  False  False  False  False  False
# 98  False  False  False  False  False  False  False  False  False  False
# 99  False  False  False  False  False  False  False  False  False  False
#
# [100 rows x 100 columns]

# %% [markdown]
# But it is way easier, using the `grep` command on the terminal

# %%
# %%bash
# grep -n Triana names_files/*.dat
# Out:
# names_files/36.dat:93:Julian Triana
# names_files/39.dat:50:Julian Triana

# %% [markdown]
# So that, we can use the files we got, and compare them with the rest

# %%
# %%bash
# for i in $(ls names_files/*.dat)
# do
#     diff $i names_files/39.dat | wc > aux.data
#     echo $i $(cat aux.data)
# done
# Out:
# names_files/0.dat 202 602 3233
# names_files/1.dat 202 602 3207
# names_files/10.dat 202 602 3192
# names_files/11.dat 202 602 3192
# names_files/12.dat 202 602 3216
# names_files/13.dat 202 602 3230
# names_files/14.dat 4 8 43
# names_files/15.dat 202 602 3244
# names_files/16.dat 202 602 3233
# names_files/17.dat 202 602 3224
# names_files/18.dat 202 602 3239
# names_files/19.dat 202 602 3226
# names_files/2.dat 202 602 3210
# names_files/20.dat 202 602 3253
# names_files/21.dat 202 602 3219
# names_files/22.dat 202 602 3228
# names_files/23.dat 202 602 3243
# names_files/24.dat 202 602 3238
# names_files/25.dat 202 602 3209
# names_files/26.dat 202 602 3249
# names_files/27.dat 202 602 3234
# names_files/28.dat 202 602 3277
# names_files/29.dat 202 602 3196
# names_files/3.dat 202 602 3218
# names_files/30.dat 202 602 3213
# names_files/31.dat 202 602 3220
# names_files/32.dat 202 602 3211
# names_files/33.dat 202 602 3207
# names_files/34.dat 202 602 3239
# names_files/35.dat 202 602 3229
# names_files/36.dat 202 598 3249
# names_files/37.dat 202 602 3190
# names_files/38.dat 202 602 3230
# names_files/39.dat 0 0 0
# names_files/4.dat 202 602 3189
# names_files/40.dat 202 598 3193
# names_files/41.dat 202 602 3228
# names_files/42.dat 202 602 3211
# names_files/43.dat 202 602 3276
# names_files/44.dat 202 602 3231
# names_files/45.dat 202 602 3201
# names_files/46.dat 202 602 3262
# names_files/47.dat 202 602 3220
# names_files/48.dat 202 602 3243
# names_files/49.dat 202 602 3218
# names_files/5.dat 202 602 3213
# names_files/50.dat 202 602 3214
# names_files/51.dat 202 602 3219
# names_files/52.dat 202 602 3267
# names_files/53.dat 202 602 3211
# names_files/54.dat 202 602 3204
# names_files/55.dat 202 602 3218
# names_files/56.dat 202 602 3255
# names_files/57.dat 202 602 3224
# names_files/58.dat 202 602 3201
# names_files/59.dat 202 602 3251
# names_files/6.dat 202 602 3220
# names_files/60.dat 202 602 3204
# names_files/61.dat 202 602 3256
# names_files/62.dat 202 602 3219
# names_files/63.dat 202 602 3227
# names_files/64.dat 202 602 3226
# names_files/65.dat 202 602 3237
# names_files/66.dat 202 602 3256
# names_files/67.dat 202 602 3231
# names_files/68.dat 202 602 3244
# names_files/69.dat 202 602 3243
# names_files/7.dat 202 602 3182
# names_files/70.dat 202 602 3241
# names_files/71.dat 202 602 3206
# names_files/72.dat 202 602 3226
# names_files/73.dat 202 602 3237
# names_files/74.dat 202 602 3281
# names_files/75.dat 202 602 3252
# names_files/76.dat 202 602 3221
# names_files/77.dat 202 602 3230
# names_files/78.dat 202 602 3218
# names_files/79.dat 202 602 3233
# names_files/8.dat 202 602 3258
# names_files/80.dat 202 602 3220
# names_files/81.dat 202 602 3204
# names_files/82.dat 202 602 3194
# names_files/83.dat 202 602 3227
# names_files/84.dat 202 602 3206
# names_files/85.dat 202 602 3230
# names_files/86.dat 202 602 3217
# names_files/87.dat 202 602 3215
# names_files/88.dat 202 602 3224
# names_files/89.dat 202 602 3233
# names_files/9.dat 202 602 3224
# names_files/90.dat 202 602 3218
# names_files/91.dat 201 597 3196
# names_files/92.dat 202 602 3225
# names_files/93.dat 202 602 3181
# names_files/94.dat 202 602 3216
# names_files/95.dat 202 602 3227
# names_files/96.dat 202 602 3210
# names_files/97.dat 202 602 3213
# names_files/98.dat 202 602 3223
# names_files/99.dat 202 602 3219
# names_files/test.dat 101 301 1604

# %% [markdown]
# So that the file 14 was copied into the 39
